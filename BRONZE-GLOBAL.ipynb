# %%
# DBTITLE 1,Cell 1
df = spark.read.table("global.bronze.olist_customers_dataset")
df1 = spark.read.table("global.bronze.olist_geolocation_dataset")
df2 = spark.read.table("global.bronze.olist_order_items_dataset")
df3 = spark.read.table("global.bronze.olist_order_payments_dataset")
df4 = spark.read.table("global.bronze.olist_order_reviews_dataset")
df5 = spark.read.table("global.bronze.olist_orders_dataset")
df6 = spark.read.table("global.bronze.olist_products_dataset")
df7 = spark.read.table("global.bronze.olist_sellers_dataset")
df8 = spark.read.table("global.bronze.olist_products_dataset_2")
df9 = spark.read.table("global.bronze.product_category_name_translation")
df10 = spark.read.table("global.bronze.olist_sellers_dataset_2")

# COMMAND ----------

# %%
display(df.limit(10))

# %%
# SALVANDO DADOS NA TABELA SILVER
df.write.mode("overwrite").saveAsTable("global.silver.olist_customers_dataset")
df1.write.mode("overwrite").saveAsTable("global.silver.olist_geolocation_dataset")
df2.write.mode("overwrite").saveAsTable("global.silver.olist_order_items_dataset")
df3.write.mode("overwrite").saveAsTable("global.silver.olist_order_payments_dataset")
df4.write.mode("overwrite").saveAsTable("global.silver.olist_order_reviews_dataset")
df5.write.mode("overwrite").saveAsTable("global.silver.olist_orders_dataset")
df6.write.mode("overwrite").saveAsTable("global.silver.olist_products_dataset")
df7.write.mode("overwrite").saveAsTable("global.silver.olist_sellers_dataset")
df8.write.mode("overwrite").saveAsTable("global.silver.olist_products_dataset_2")
df9.write.mode("overwrite").saveAsTable("global.silver.product_category_name_translation")
df10.write.mode("overwrite").saveAsTable("global.silver.olist_sellers_dataset_2")
