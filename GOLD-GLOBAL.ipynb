# %%
# MAGIC # LEITURA DA CAMADA - GOLD

df1 = spark.read.table("global.gold.gold_categorias_produtos")
df2 = spark.read.table("global.gold.gold_geografias")
df3 = spark.read.table("global.gold.gold_performance_vendedores")
df4 = spark.read.table("global.gold.gold_satisfacao_nps")
df5 = spark.read.table("global.gold.gold_segmentacao_clientes")
df6 = spark.read.table("global.gold.gold_vendas_por_periodo")




# COMMAND ----------

display(df1.limit(10))
